# %%
# !git clone https://github.com/e11824496/SPEML_E2.git
# Out:
# Cloning into 'SPEML_E2'...
# remote: Enumerating objects: 159, done.
# remote: Counting objects: 100% (159/159), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 159 (delta 21), reused 155 (delta 20), pack-reused 0
# Receiving objects: 100% (159/159), 16.11 MiB | 12.67 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# %cd ./SPEML_E2/WatermarkNN/
# Out:
# /content/SPEML_E2/WatermarkNN

# %%
from helpers.loaders import *
from helpers.utils import load_yaml

args = load_yaml('resnet_cifar_config.yaml')

# %%
from train import train
train(args)
# Out:
# /content/SPEML_E2/WatermarkNN/trainer.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# ==> Preparing data..
# Using CIFAR10 dataset.
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 42848621.56it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Loading watermark images
# ==> Building model..
# Using CUDA
# Parallel training on 1 GPUs.
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 0
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 1
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 2
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 3
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 4
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 5
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 6
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 7
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 8
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 9
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 10
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 11
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 12
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 13
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 14
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 15
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 16
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 17
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 18
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 19
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 20
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 21
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 22
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 23
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 24
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 25
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 26
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 27
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 28
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 29
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 30
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 31
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 32
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 33
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 34
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 35
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 36
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 37
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 38
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 39
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 40
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 41
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 42
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 43
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 44
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 45
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 46
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 47
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 48
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 49
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 50
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 51
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 52
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 53
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 54
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 55
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 56
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 57
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 58
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 59
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Saving..
# (tensor(92.4500), tensor(100.))

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from predict import predict
predict(args)
# Out:
# Loading watermark images
# ==> Resuming from checkpoint..
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from fine_tune import fine_tune
fine_tune(args)
# Out:
# /content/SPEML_E2/WatermarkNN/fine_tune.py:58: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if device is 'cuda':
# /content/SPEML_E2/WatermarkNN/fine_tune.py:88: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   'net': net.module if device is 'cuda' else net,
# ==> Preparing data..
# Using CIFAR10 dataset.
# Files already downloaded and verified
# Files already downloaded and verified
# Loading watermark images
# ==> loading model...
# Using CUDA
# Parallel training on 1 GPUs.
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 59
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 60
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 61
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 62
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 63
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 64
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 65
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 66
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 67
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 68
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 69
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 70
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 71
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 72
#   0%|          | 0/500 [00:00<?, ?it/s]
# Test acc:
#   0%|          | 0/100 [00:00<?, ?it/s]
# WM acc:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saving..
#
# Epoch: 73
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-46c53eeefb7f> in <cell line: 2>()
#       1 from fine_tune import fine_tune
# ----> 2 fine_tune(args)
#
# /content/SPEML_E2/WatermarkNN/fine_tune.py in fine_tune(args)
#      75     # start training
#      76     for epoch in range(start_epoch, start_epoch + args.max_epochs):
# ---> 77         train_epoch(epoch, net, criterion, optimizer, logfile,
#      78                 trainloader, device, wmloader=False, tune_all=args.tunealllayers)
#      79
#
# /content/SPEML_E2/WatermarkNN/trainer.py in train_epoch(epoch, net, criterion, optimizer, logfile, loader, device, wmloader, tune_all)
#      44
#      45         optimizer.zero_grad()
# ---> 46         outputs = net(inputs)
#      47         loss = criterion(outputs, targets)
#      48
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     167
#     168             if len(self.device_ids) == 1:
# --> 169                 return self.module(*inputs[0], **kwargs[0])
#     170             replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     171             outputs = self.parallel_apply(replicas, inputs, kwargs)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/SPEML_E2/WatermarkNN/models/resnet.py in forward(self, x)
#     191     def forward(self, x):
#     192         out = F.relu(self.bn1(self.conv1(x)))
# --> 193         out = self.layer1(out)
#     194         out = self.layer2(out)
#     195         out = self.layer3(out)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/SPEML_E2/WatermarkNN/models/resnet.py in forward(self, x)
#      65         out = F.relu(self.bn1(x))
#      66         shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
# ---> 67         out = self.conv1(out)
#      68         out = self.conv2(F.relu(self.bn2(out)))
#      69         out += shortcut
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# KeyboardInterrupt:

# %%
predict(args)
# Out:
# Loading watermark images
# ==> Resuming from checkpoint..
#   0%|          | 0/1 [00:00<?, ?it/s]
